But pieces remain. When Shireen makes sweet tea, the aroma pulls me back to our old veranda. Rahim plays Rafi songs; I hum along, eyes closed. Grandkids laugh—I pat their heads, call them by old pet names. Fatima visits, recites Nazrul—“Aaj shudhu ei kotha mone pore”—and fragments return to my tongue.

I forget today’s date, names of new neighbors, sometimes even my grandchildren’s ages. Yet love stays. Pride in my railway years stays. The boy who dreamed under mango trees still dreams, even if the dreams fade like morning mist.
""".strip()

# === PART 2: 100 Questions (numbered) ===
questions = [
    "What is my full name?",
    "When was I born?",
    "Where was I born?",
    "What was my father’s name and occupation?",
    "What was my mother’s name?",
    "How many siblings did I have?",
    "What was my position among the siblings?",
    "Which poets did I love most as a child?",
    "Which school did I attend for matriculation?",
    "In which year did I pass matriculation?",
    "Which college did I attend for intermediate?",
    "In which year did I join the railway department?",
    "What was my starting position in the railway?",
    "In which year did I become station master?",
    "What was my highest position?",
    "In which year did I move to Dhaka for posting?",
    "When did I retire from the railway?",
    "How many years did I serve in the railway?",
    "When and where did I marry?",
    "What was my wife’s full name?",
    "In which year was my eldest son Rahim born?",
    "In which year was my daughter Fatima born?",
    "In which year was my youngest son Jamal born?",
    "In which year did we build our own house in Mirpur?",
    "What type of house did we build?",
    "Which flowers did I plant proudly in the garden?",
    "How did I like my morning tea?",
    "Which old music player did we have at home?",
    "Name three favorite male singers of mine.",
    "Name two favorite female singers of mine.",
    "Name one favorite Mohammed Rafi song of mine.",
    "Name one favorite Lata Mangeshkar song of mine.",
    "Which national cricket team did I support after 1971?",
    "Which tournament victory in 1997 made me happy?",
    "What is my absolute favorite fish?",
    "How did I like hilsa prepared best?",
    "Name two other favorite dishes my wife made.",
    "Which sweet dish from Bogra did I love?",
    "What type of food spice level did I prefer?",
    "Which mosque did I serve as treasurer?",
    "For how many years was I treasurer?",
    "What kind help did I give to neighbors?",
    "What did children in the neighborhood call me?",
    "During which war was I posted in Chittagong?",
    "What small act of help did I do during the war?",
    "Where did Ayesha and I travel after retirement?",
    "In which year did Ayesha first have diabetes issues?",
    "When did Ayesha pass away?",
    "What was the main cause of Ayesha’s death?",
    "What do I still do every evening with Ayesha’s photo?",
    "In which year did the first clear signs of dementia appear?",
    "What medical condition was diagnosed in 2020?",
    "By which year did I need help with daily activities?",
    "What is the current date mentioned?",
    "Where do I live now in 2026?",
    "With whose family do I stay?",
    "What do I sometimes believe about my job due to dementia?",
    "Which train do I sometimes wait for?",
    "What aroma brings back old veranda memories?",
    "Which singer’s songs make me hum along now?",
    "What do I do when grandchildren laugh?",
    "Who sometimes recites Nazrul to me?",
    "Which Nazrul line sometimes comes back to me?",
    "What was my pet name for young grandchildren?",
    "What was the old radio-cassette brand we had?",
    "Which section of Mirpur was our house in?",
    "What color was our house floor?",
    "Which creeper climbed our gate?",
    "Name one Kishore Kumar song I liked.",
    "Which year did Bangladesh beat Australia that I celebrated?",
    "What pitha did I enjoy in winter?",
    "What kind of gur did I like with pitha?",
    "Name one thing I did for orphans in the community.",
    "Which newspaper did I read in the morning?",
    "What did I flag down once to save a child?",
    "Name one place we visited in the Chittagong Hill Tracts.",
    "What did I search for in the kitchen sometimes?",
    "Which of my children lives in Chittagong now?",
    "What do Rahim’s children call me?",
    "What type of roses did I grow—color and variety?",
    "Which old exercise book did I use for poetry?",
    "Under which tree did I recite “Bidrohi”?",
    "Which fruit tree was behind our village house?",
    "In which year did we get independence (that I remember)?",
    "What was one duty I did as senior station master?",
    "Name one old Hindi sad song singer I liked.",
    "Which sweet from Kolkata-style shops did I enjoy?",
    "What was the date format I used on old letters?",
    "Which Bengali month did I associate with hilsa season?",
    "What did I collect quietly for poor families?",
    "Name one grandchild activity I enjoyed teaching.",
    "Which department exam helped me get promoted?",
    "Which ICC event in 2015 made me emotional?",
    "Which child brings new roses sometimes?",
    "What slips away first in my memory—names or dates?",
    "Which poem fragment still reaches my lips?",
    "Despite forgetting, what stays deepest inside me?"
]

# === PART 3: 100 Correct Answers (in the same order) ===
answers = [
    "Abdul Karim Chowdhury",
    "15 June 1942",
    "Bishwanath village near Sylhet",
    "Ismail Hossain, farmer",
    "Rahima Khatun",
    "Four siblings",
    "Second son",
    "Kazi Nazrul Islam and Rabindranath Tagore",
    "Sylhet Government Pilot High School",
    "1958",
    "MC College, Sylhet",
    "1962",
    "Junior clerk in accounts",
    "1970",
    "Senior station master",
    "1982",
    "30 June 2000",
    "38 years",
    "12 February 1968",
    "Ayesha Begum",
    "1969",
    "1972",
    "1976",
    "1985",
    "Two-storey with tin roof",
    "Red hybrid tea roses, jasmine, marigold, beli creeper",
    "Strong black tea with two heaped spoons sugar, no milk",
    "Old Philips cassette player",
    "Mohammed Rafi, Mukesh, Kishore Kumar",
    "Lata Mangeshkar (and others from golden era)",
    "Chura Liya Hai Tumne Jo Dil Ko",
    "Lag Ja Gale",
    "Bangladesh",
    "1997 ICC Trophy",
    "Hilsa (ilish)",
    "Doi ilish or fried with green chili",
    "Beef bhuna, shutki bhorta",
    "Mishti doi",
    "Mild, not very spicy",
    "Masjid-e-Baitul Mamur",
    "Twelve years",
    "Lent small money without interest",
    "Karim Uncle",
    "1971 Liberation War",
    "Hid documents and guided people",
    "Cox’s Bazar, Sylhet, Rangamati",
    "2013 (major complications)",
    "18 March 2015",
    "Diabetes complications",
    "Talk to it every evening",
    "Around 2018",
    "Alzheimer’s type dementia",
    "By 2023",
    "March 2026",
    "Mohammadpur, Dhaka flat",
    "Eldest son Rahim’s family",
    "Still working at Kamalapur station",
    "8:15 Upaban Express",
    "Sweet tea aroma",
    "Mohammed Rafi (and others)",
    "Pat their heads, smile",
    "Daughter Fatima",
    "Aaj shudhu ei kotha mone pore",
    "Old pet names",
    "Philips",
    "Section 10",
    "Red oxide",
    "Beli creeper",
    "Mere Sapno Ki Rani",
    "2005",
    "Patishapta",
    "Khejurer gur",
    "Collected funds",
    "Prothom Alo",
    "Express train",
    "Rangamati",
    "Ayesha",
    "Fatima",
    "Dada / Nana",
    "Red hybrid tea roses",
    "Old exercise books",
    "Mango tree",
    "Mango tree",
    "1971",
    "Train inspections, scheduling",
    "Mukesh",
    "Roshogolla / rosh malai",
    "Day/Month/Year",
    "Ashwin / Kartik (monsoon)",
    "Funds / donations",
    "Nazrul poems, railway stories",
    "Departmental exams",
    "2015 World Cup quarter-final",
    "Rahim",
    "Both, but recent names/dates first",
    "Nazrul lines / fragments",
    "Love, pride, and the boy who loved poetry"
]

# === HELPER FUNCTIONS ===
def print_slow(text, delay=0.03):
    """Prints text character by character with a delay."""
    for char in text:
        print(char, end='', flush=True)
        time.sleep(delay)
    print()

def clean_input(text):
    """Cleans user input or answer for comparison: strips whitespace, converts to lowercase."""
    if isinstance(text, str):
        return text.strip().lower()
    return str(text).strip().lower()

def display_intro():
    """Displays the quiz introduction."""
    os.system('cls' if os.name == 'nt' else 'clear')  # clear screen
    print("="*70)
    print_slow("  I am Abdul Karim Chowdhury. My memory is a little weak now...")
    print_slow("  But let's see what I still remember. You will help me, right?")
    print("="*70)
    print("\nPersonal data is loaded. We have 100 questions about my life.")
    print("I will ask you one by one. You answer. I will tell if correct.")
    print("Type 'quit' or 'q' any time to stop.\n")
    input("Press Enter when you are ready... ")

def check_answer(user_answer, correct_answer_options):
    """Checks if the user's answer is correct, considering multiple correct forms.
    Args:
        user_answer (str): The cleaned user's input.
        correct_answer_options (str): The single correct answer from the list, potentially containing multiple options separated by '/'.
    Returns:
        bool: True if the answer is correct, False otherwise.
    """
    cleaned_user_answer = clean_input(user_answer)

    # Handle cases where correct answer might have multiple acceptable forms (e.g., "Roshogolla / rosh malai")
    # Split by '/' and check each option.
    possible_correct_answers = [clean_input(opt) for opt in correct_answer_options.split('/')]

    # Also check if the user's answer is a substring of any correct option, or vice-versa, for flexibility
    # This is a bit more permissive, good for a quiz where slight variations are acceptable.
    for option in possible_correct_answers:
        if cleaned_user_answer == option: # Exact match
            return True
        if cleaned_user_answer in option: # User's answer is part of the correct answer
            return True
        if option in cleaned_user_answer: # Correct answer is part of the user's answer (e.g., 'ilish' for 'hilsa (ilish)')
            return True
    return False

def display_results(correct_count, total_asked):
    """Displays the final quiz results."""
    print("\n" + "="*70)
    print_slow(f"  We finished {total_asked} questions.")
    print_slow(f"  You got {correct_count} correct. {correct_count}/{total_asked}")
    if total_asked > 0:
        percent = round((correct_count / total_asked) * 100, 1)
        print_slow(f"  Score: {percent}%")
    print_slow("  Thank you for helping an old man remember...")
    print("="*70)

# === MAIN PROGRAM ===
def main():
    display_intro()

    # Shuffle questions for variety
    indices = list(range(len(questions)))
    random.shuffle(indices)

    correct_count = 0
    total_asked = 0

    for i, idx in enumerate(indices, 1):
        q = questions[idx]
        correct_ans_raw = answers[idx]

        print(f"\n[{i}/{len(questions)}]  {q}")
        user_ans = input("→ Your answer: ").strip()

        if clean_input(user_ans) in ['quit', 'q', 'exit']:
            break

        total_asked += 1
        if check_answer(user_ans, correct_ans_raw):
            print_slow("  ✓ Yes! That is correct.", 0.02)
            correct_count += 1
        else:
            print_slow(f"  ✗ Not quite... I think it was: {answers[idx]}", 0.02)

        print("-"*60)

    display_results(correct_count, total_asked)

if __name__ == "__main__":
    try:
        main()
    except KeyboardInterrupt:
        print("\n\nGoodbye. Allah hafiz.")
# Out:
# ...
#   I am Abdul Karim Chowdhury. My memory is a little weak now...
#   But let's see what I still remember. You will help me, right?
# ...
#
# Personal data is loaded. We have 100 questions about my life.
# I will ask you one by one. You answer. I will tell if correct.
# Type 'quit' or 'q' any time to stop.
#
#
# [1/97]  Where was I born?
#   ✗ Not quite... I think it was: Bishwanath village near Sylhet
# ------------------------------------------------------------
#
# [2/97]  Name two favorite female singers of mine.
#   ✗ Not quite... I think it was: Lata Mangeshkar (and others from golden era)
# ------------------------------------------------------------
#
# [3/97]  In which year did we build our own house in Mirpur?
#   ✓ Yes! That is correct.
# ------------------------------------------------------------
#
# [4/97]  What medical condition was diagnosed in 2020?
#   ✓ Yes! That is correct.
# ------------------------------------------------------------
#
# ...
